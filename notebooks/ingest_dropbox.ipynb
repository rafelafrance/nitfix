# %% [markdown]
# # Ingest Data from Dropbox

# %%
import os
import re
from pathlib import Path

import pandas as pd
from dotenv import load_dotenv, find_dotenv
import dropbox

import lib.db as db

# %%
load_dotenv(find_dotenv())

CXN = db.connect()
INTERIM_DATA = Path('..') / 'data' / 'interim'
PROCESSED_DATA = Path('..') / 'data' / 'processed'

# %%
DROPBOX = os.getenv('DROPBOX')

dbx = dropbox.Dropbox(DROPBOX)

# %% [markdown]
# ### Ingest Nitfix 1

# %%
file_name = 'nitfix01.csv'

csv_path = str(INTERIM_DATA / file_name)
dbx_path = 'id:zSBrtnqOfSAAAAAAAAAAKw/5657_Nit_Fix_I.reconcile.4.2.csv'

file_metadata = dbx.files_download_to_file(csv_path, dbx_path)

df = pd.read_csv(csv_path)
columns = {}
for old in df.columns:
    new = old.lower()
    new = new.replace('⁰', 'deg')
    new = new.replace("''", 'sec')
    new = new.replace("'", 'min')
    new = re.sub(r'[^a-z0-9_]+', '_', new)
    new = re.sub(r'^_|_$', '', new)
    columns[old] = new
columns['subject_qr_code'] = 'sample_id'

df.rename(columns=columns, inplace=True)

df.to_sql('reconciled', CXN, if_exists='replace')

csv_path = PROCESSED_DATA / file_name
df.to_csv(csv_path, index=False)

df.head()
# Out:
#    subject_id                             country  state_province    county  \
# 0    16192935            United States of America  North Carolina     Wayne
# 1    16192937            United States of America         Arizona  Maricopa
# 2    16192938                               Gabon     Ogooué-Lolo       NaN
# 3    16192939        Tanzania, United Republic of           Tanga       NaN
# 4    16192941  Congo (Democratic Republic of the)   Kasaï-Central       NaN
#
#                                             location minimum_elevation  \
# 0  Town of Fremont, along NC Rt.222, east of Evan...               NaN
# 1  Salt Rivr at 35th Avenue bridge in Phoenix, ju...              1022
# 2  Makande surroundings, c. 65 km SSW of Booué. I...               NaN
# 3  Mkaramo Parish, Mkwaja Subchiefeom, Mwera Chie...               150
# 4                                     Babadi - Kasai               NaN
#
#   maximum_elevation main_dropdown latitude_deg latitude_min  \
# 0               NaN          feet           35           32
# 1               NaN          feet    33.411913          NaN
# 2               NaN           NaN          - 0         41 S
# 3               NaN          feet          NaN          NaN
# 4               NaN       unknown          NaN          NaN
#
#                    ...                         month_1      day_1 year_1  \
# 0                  ...                   9 - September         25   2011
# 1                  ...                     1 - January         21   2012
# 2                  ...                    2 - February         11   1999
# 3                  ...                        7 - July         10   1957
# 4                  ...                   12 - December  Not Shown   1934
#
#   month_2 day_2 year_2 subject_image_name subject_nybg_bar_code  \
# 0     NaN   NaN    NaN       R0001220.JPG          NYBG 3196996
# 1     NaN   NaN    NaN       R0001205.JPG          NYBG 3196995
# 2     NaN   NaN    NaN       R0001202.JPG          NYBG 3196994
# 3     NaN   NaN    NaN       R0001201.JPG          NYBG 3196992
# 4     NaN   NaN    NaN       R0001199.JPG          NYBG 3196991
#
#      subject_resolved_name                             sample_id
# 0        Senna obtusifolia  8e37959f-dfa6-44b6-a201-b94215340016
# 1      Senna artemisioides  90a9d5ee-a1c6-4dd3-b6b1-6932ea796abd
# 2   Scorodophloeus zenkeri  90f68e06-c5cb-48dc-9de1-5c0512314486
# 3  Scorodophloeus fischeri  90fb8362-a4ed-407d-a8b1-32dc56506101
# 4         Leonardoxa romii  911525c9-04f7-4213-8781-a9842216c2d8
#
# [5 rows x 28 columns]
