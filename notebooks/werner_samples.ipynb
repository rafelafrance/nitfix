# %%
import os
from glob import glob
from pathlib import Path
from datetime import datetime
import pandas as pd
import lib.db as db
import lib.google as google
import lib.util as util

# %%
CXN = db.connect_up()

INTERIM_DATA = Path('..') / 'data' / 'interim'
EXTERNAL_DATA = Path('..') / 'data' / 'external'

# %%
sql = """SELECT scientific_name, id FROM taxon_ids"""
taxon_ids = pd.read_sql(sql, CXN).set_index('scientific_name').id.to_dict()
len(taxon_ids)
# Out:
# 12794

# %%
def get_scientific_names():
    sql = """SELECT scientific_name, synonyms, family FROM taxonomy"""
    taxonomy = pd.read_sql(sql, CXN)

    synonyms = taxonomy.synonyms.str.split(r'\s*[;,]\s*', expand=True)

    taxonomy = pd.concat([taxonomy, synonyms], axis=1)
    synonyms = taxonomy.melt(
        id_vars=['scientific_name'],
        value_vars=synonyms.columns,
        value_name='synonym')

    synonyms = synonyms[synonyms.synonym.notna()].drop('variable', axis=1)
    synonyms = synonyms.set_index('synonym').scientific_name.to_dict()

    sci_names = taxonomy.scientific_name.tolist()

    return sci_names, synonyms

# %%
def read_werner_data():
    excel_path = EXTERNAL_DATA / 'NitFixWernerEtAl2014.xlsx'
    werner = pd.read_excel(excel_path)
    drops = """Legume Likelihood_non-precursor
        Likelihood_precursor Likelihood_fixer Likelihood_stable_fixer
        Most_likely_state Corrected_lik_precursor
        Corrected_lik_stable_fixer""".split()
    werner = werner.drop(
        drops, axis=1).rename(
            columns={
                'NFC': 'nfc',
                'Species': 'scientific_name',
                'Family': 'family_w',
                'Order': 'order'
            })
    is_nfc = werner.nfc == 'Yes'
    return werner[is_nfc]

# %%
sci_names, synonyms = get_scientific_names()
werner = read_werner_data()

print(werner.shape)
is_sci_name = werner.scientific_name.isin(sci_names)
is_synonym = werner.scientific_name.isin(synonyms)
update_it = ~is_sci_name & is_synonym
print(update_it.sum())

werner[update_it]
# Out:
# (1709, 7)
# 38
#                scientific_name  nfc         order       family_w Data_fixing  \
# 3               Inga marginata  Yes       Fabales       Fabaceae         Yes
# 36               Samanea saman  Yes       Fabales       Fabaceae         Yes
# 49           Parkia roxburghii  Yes       Fabales       Fabaceae          No
# 58         Lysiloma tergeminum  Yes       Fabales       Fabaceae         Yes
# 78           Acacia euthycarpa  Yes       Fabales       Fabaceae         Yes
# 199       Vachellia farnesiana  Yes       Fabales       Fabaceae         Yes
# 268             Entada rheedei  Yes       Fabales       Fabaceae         Yes
# 285    Parkinsonia microphylla  Yes       Fabales       Fabaceae          No
# 296          Gleditsia caspica  Yes       Fabales       Fabaceae          No
# 298           Gleditsia rolfei  Yes       Fabales       Fabaceae          No
# 302        Gymnocladus dioicus  Yes       Fabales       Fabaceae          No
# 422    Astragalus membranaceus  Yes       Fabales       Fabaceae         Yes
# 727         Lotus salsuginosus  Yes       Fabales       Fabaceae         Yes
# 728            Lotus scoparius  Yes       Fabales       Fabaceae         Yes
# 729              Lotus rigidus  Yes       Fabales       Fabaceae         Yes
# 730         Lotus grandiflorus  Yes       Fabales       Fabaceae         Yes
# 735         Lotus crassifolius  Yes       Fabales       Fabaceae         Yes
# 769         Sesbania vesicaria  Yes       Fabales       Fabaceae         Yes
# 770     Pediomelum argophyllum  Yes       Fabales       Fabaceae         Yes
# 771      Pediomelum esculentum  Yes       Fabales       Fabaceae         Yes
# 772    Psoralidium lanceolatum  Yes       Fabales       Fabaceae         Yes
# 776       Orbexilum onobrychis  Yes       Fabales       Fabaceae         Yes
# 794   Amphicarpaea edgeworthii  Yes       Fabales       Fabaceae         Yes
# 905          Millettia pinnata  Yes       Fabales       Fabaceae         Yes
# 1055        Pterodon pubescens  Yes       Fabales       Fabaceae          No
# 1130         Cytisus nigricans  Yes       Fabales       Fabaceae         Yes
# 1215       Cyclopia subternata  Yes       Fabales       Fabaceae         Yes
# 1228         Calpurnia intrusa  Yes       Fabales       Fabaceae         Yes
# 1297         Machaerium hirtum  Yes       Fabales       Fabaceae         Yes
# 1379       Alchemilla vulgaris  Yes       Rosales       Rosaceae          No
# 1401          Rubus fruticosus  Yes       Rosales       Rosaceae          No
# 1426     Crataegus curvisepala  Yes       Rosales       Rosaceae          No
# 1428     Stranvaesia davidiana  Yes       Rosales       Rosaceae          No
# 1493       Artocarpus lakoocha  Yes       Rosales       Moraceae          No
# 1549       Ziziphus mauritiana  Yes       Rosales     Rhamnaceae          No
# 1569       Coriaria intermedia  Yes  Cucurbitales   Coriariaceae         Yes
# 1580         Casuarina stricta  Yes       Fagales  Casuarinaceae         Yes
# 1654   Lithocarpus densiflorus  Yes       Fagales       Fagaceae          No
#
#           Source                  Source2
# 3         Manual               Roggy_1999
# 36    Sprent2009               Appendices
# 49          GRIN                     None
# 58    Sprent2009               Appendices
# 78          GRIN                     None
# 199         GRIN                     None
# 268   Sprent2009               Appendices
# 285         GRIN                     None
# 296         GRIN                     None
# 298         GRIN                     None
# 302         GRIN                     None
# 422   Sprent2009               Appendices
# 727   Sprent2009               Appendices
# 728   Sprent2009               Appendices
# 729   Sprent2009               Appendices
# 730   Sprent2009               Appendices
# 735   Sprent2009               Appendices
# 769   Sprent2009               Appendices
# 770   Sprent2009               Appendices
# 771   Sprent2009               Appendices
# 772         GRIN                     None
# 776   Sprent2009               Appendices
# 794   Sprent2009               Appendices
# 905   Sprent2009               Appendices
# 1055         TRY                   Craine
# 1130  Sprent2009               Appendices
# 1215  Sprent2009               Appendices
# 1228  Sprent2009               Appendices
# 1297  Sprent2009               Appendices
# 1379         TRY                   Kattge
# 1401         TRY                   Wright
# 1426         TRY                   Wright
# 1428         TRY                   Wright
# 1493         TRY                   Wright
# 1549         TRY                   Craine
# 1569      Manual  Rodriguez-Barrueco_1969
# 1580      Manual  Rodriguez-Barrueco_1969
# 1654         TRY                   Wright

# %%
werner['synonym'] = ''
werner.loc[update_it, 'synonym'] = werner.loc[update_it, 'scientific_name']

# %%
werner.loc[update_it, 'scientific_name'] = \
    werner.loc[update_it, 'scientific_name'].apply(lambda x: synonyms[x])

# %%
werner[update_it]
# Out:
#                    scientific_name  nfc         order       family_w  \
# 3                   Inga semialata  Yes       Fabales       Fabaceae
# 36                   Albizia saman  Yes       Fabales       Fabaceae
# 49                Parkia timoriana  Yes       Fabales       Fabaceae
# 58              Lysiloma tergemina  Yes       Fabales       Fabaceae
# 1228         Yes  Sprent2009               Appendices
# 1297         Yes  Sprent2009               Appendices
# 1379          No         TRY                   Kattge
# 1401          No         TRY                   Wright
# 1426          No         TRY                   Wright
# 1428          No         TRY                   Wright
# 1493          No         TRY                   Wright
# 1549          No         TRY                   Craine
# 1569         Yes      Manual  Rodriguez-Barrueco_1969
# 1580         Yes      Manual  Rodriguez-Barrueco_1969
# 1654          No         TRY                   Wright
#
#                        synonym
# 3               Inga marginata
# 36               Samanea saman
# 49           Parkia roxburghii
# 58         Lysiloma tergeminum
# 78           Acacia euthycarpa
# 199       Vachellia farnesiana
# 268             Entada rheedei
# 285    Parkinsonia microphylla
# 296          Gleditsia caspica
# 298           Gleditsia rolfei
# 302        Gymnocladus dioicus
# 422    Astragalus membranaceus
# 727         Lotus salsuginosus
# 728            Lotus scoparius
# 729              Lotus rigidus
# 730         Lotus grandiflorus
# 735         Lotus crassifolius
# 769         Sesbania vesicaria
# 770     Pediomelum argophyllum
# 771      Pediomelum esculentum
# 772    Psoralidium lanceolatum
# 776       Orbexilum onobrychis
# 794   Amphicarpaea edgeworthii
# 905          Millettia pinnata
# 1055        Pterodon pubescens
# 1130         Cytisus nigricans
# 1215       Cyclopia subternata
# 1228         Calpurnia intrusa
# 1297         Machaerium hirtum
# 1379       Alchemilla vulgaris
# 1401          Rubus fruticosus
# 1426     Crataegus curvisepala
# 1428     Stranvaesia davidiana
# 1493       Artocarpus lakoocha
# 1549       Ziziphus mauritiana
# 1569       Coriaria intermedia
# 1580         Casuarina stricta
# 1654   Lithocarpus densiflorus

# %%
found = werner.scientific_name.isin(sci_names)
first = werner.scientific_name.duplicated()
print(found.sum())
print(first.sum())
werner[first]
# Out:
# 1675
# 8
#                  scientific_name  nfc         order       family_w  \
# 81            Acacia calamifolia  Yes       Fabales       Fabaceae
# 230             Parkia timoriana  Yes       Fabales       Fabaceae
# 300               Gleditsia fera  Yes       Fabales       Fabaceae
# 795       Amphicarpaea bracteata  Yes       Fabales       Fabaceae
# 1224            Cyclopia falcata  Yes       Fabales       Fabaceae
# 1551             Ziziphus jujuba  Yes       Rosales     Rhamnaceae
# 1570           Coriaria japonica  Yes  Cucurbitales   Coriariaceae
# 1580  Allocasuarina verticillata  Yes       Fagales  Casuarinaceae
#
#      Data_fixing      Source                  Source2            synonym
# 81           Yes  Sprent2009               Appendices
# 230           No  Sprent2001                 Table5.4
# 300           No        GRIN                     None
# 795          Yes  Sprent2009               Appendices
# 1224         Yes  Sprent2009               Appendices
# 1551          No         TRY                   Wright
# 1570         Yes      Manual             Becking_1975
# 1580         Yes      Manual  Rodriguez-Barrueco_1969  Casuarina stricta

# %%
dups = werner.scientific_name.duplicated(keep=False)
werner[dups]
# Out:
#                  scientific_name  nfc         order       family_w  \
# 49              Parkia timoriana  Yes       Fabales       Fabaceae
# 78            Acacia calamifolia  Yes       Fabales       Fabaceae
# 81            Acacia calamifolia  Yes       Fabales       Fabaceae
# 230             Parkia timoriana  Yes       Fabales       Fabaceae
# 298               Gleditsia fera  Yes       Fabales       Fabaceae
# 300               Gleditsia fera  Yes       Fabales       Fabaceae
# 794       Amphicarpaea bracteata  Yes       Fabales       Fabaceae
# 795       Amphicarpaea bracteata  Yes       Fabales       Fabaceae
# 1215            Cyclopia falcata  Yes       Fabales       Fabaceae
# 1224            Cyclopia falcata  Yes       Fabales       Fabaceae
# 1549             Ziziphus jujuba  Yes       Rosales     Rhamnaceae
# 1551             Ziziphus jujuba  Yes       Rosales     Rhamnaceae
# 1569           Coriaria japonica  Yes  Cucurbitales   Coriariaceae
# 1570           Coriaria japonica  Yes  Cucurbitales   Coriariaceae
# 1578  Allocasuarina verticillata  Yes       Fagales  Casuarinaceae
# 1580  Allocasuarina verticillata  Yes       Fagales  Casuarinaceae
#
#      Data_fixing      Source                  Source2  \
# 49            No        GRIN                     None
# 78           Yes        GRIN                     None
# 81           Yes  Sprent2009               Appendices
# 230           No  Sprent2001                 Table5.4
# 298           No        GRIN                     None
# 300           No        GRIN                     None
# 794          Yes  Sprent2009               Appendices
# 795          Yes  Sprent2009               Appendices
# 1215         Yes  Sprent2009               Appendices
# 1224         Yes  Sprent2009               Appendices
# 1549          No         TRY                   Craine
# 1551          No         TRY                   Wright
# 1569         Yes      Manual  Rodriguez-Barrueco_1969
# 1570         Yes      Manual             Becking_1975
# 1578         Yes      Manual             Swensen_1996
# 1580         Yes      Manual  Rodriguez-Barrueco_1969
#
#                        synonym
# 49           Parkia roxburghii
# 78           Acacia euthycarpa
# 81
# 230
# 298           Gleditsia rolfei
# 300
# 794   Amphicarpaea edgeworthii
# 795
# 1215       Cyclopia subternata
# 1224
# 1549       Ziziphus mauritiana
# 1551
# 1569       Coriaria intermedia
# 1570
# 1578
# 1580         Casuarina stricta

# %%
in_taxo = werner[found & ~first]
print(in_taxo.shape)
in_taxo.head()
# Out:
# 1675
# 8
# (1667, 7)
#    scientific_name  nfc    order  family_w Data_fixing      Source  \
# 0     Inga acreana  Yes  Fabales  Fabaceae         Yes  Sprent2009
# 1  Inga densiflora  Yes  Fabales  Fabaceae         Yes        GRIN
# 2     Inga laurina  Yes  Fabales  Fabaceae         Yes      Manual
# 3   Inga semialata  Yes  Fabales  Fabaceae         Yes      Manual
# 4  Inga cinnamomea  Yes  Fabales  Fabaceae         Yes      Manual
#
#          Source2
# 0     Appendices
# 1           None
# 2  De_Faria_2010
# 3     Roggy_1999
# 4  De_Faria_2010

# %%
has_id = in_taxo.scientific_name.isin(taxon_ids)

should_sample = in_taxo[~has_id]

print(should_sample.shape)
should_sample.head()
# Out:
# (435, 7)
#      scientific_name  nfc    order  family_w Data_fixing      Source  \
# 0       Inga acreana  Yes  Fabales  Fabaceae         Yes  Sprent2009
# 5       Inga nobilis  Yes  Fabales  Fabaceae         Yes      Manual
# 10   Inga pezizifera  Yes  Fabales  Fabaceae         Yes      Manual
# 11  Inga cayennensis  Yes  Fabales  Fabaceae         Yes      Manual
# 13  Inga macrophylla  Yes  Fabales  Fabaceae         Yes      Manual
#
#           Source2
# 0      Appendices
# 5   De_Faria_2010
# 10  De_Faria_2010
# 11  De_Faria_2010
# 13  De_Faria_2010

# %%
should_sample.to_csv(INTERIM_DATA / 'werner_not_sampled.csv', index=False)
